# %% [markdown]
# # Setup of wandb

# %%
# !pip install wandb -q

# %%
import os
os._exit(0)

# %%
import os
os.environ["WANDB_API_KEY"] = "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"

# %%
import wandb
wandb.login()

# %%
wandb.init(
    project="23f2000441-t12026",
    name="baseline-model"
